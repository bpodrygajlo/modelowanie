# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/rij/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
def euler(initial_x, initial_y, dy, y = None, step = 0.1):
    count = np.ceil(10.0/step)
    X = np.linspace(initial_x,initial_x+10,count)
    Y = np.zeros_like(X)
    Y[0] = initial_y
    for i in np.arange(1,count):
        Y[i] = Y[i-1]+dy(X[i-1],Y[i-1])*step
    plt.figure(figsize = (9,9))
    plt.subplot(3,1,1)
    plt.plot(X,Y, color = 'blue', label ='approximation')
    plt.legend(loc = 'upper left')
    if not y is None:
        plt.plot(X,y(X),color = 'red', label='real value')
        plt.legend(loc = 'upper left')
        plt.subplot(3,1,2)
        L = y(X) - np.roll(y(X),1)- step*dy(np.roll(X,1),np.roll(y(X),1))
        plt.plot(X[1:],np.abs(L[1:]),label = 'local error')
        plt.legend(loc = 'upper left')        
        plt.subplot(3,1,3)
        plt.plot(X,np.abs(Y-y(X)),label ='global error')
        plt.legend(loc = 'upper left')

# %% [markdown]
# funkcja $ e^t $

# %%
euler(0,1,lambda x,y: np.exp(x),y = lambda x: np.exp(x), step=0.1)
# Out:
# /home/rij/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:7: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %% [markdown]
# Zadanie C2.6 a)

# %%
euler(1,2,lambda x,y: 2/(x*y**2),y = lambda x: (6*np.log(x)+8)**(1.0/3.0), step=0.1)
# Out:
# /home/rij/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:7: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %% [markdown]
# Zadanie 2.5 b)

# %%
euler(0,0,lambda x,y: 1.0 - y**2.0,y = lambda x: (np.exp(2*x) - 1)/(1+np.exp(2*x)),step = 0.01)
# Out:
# /home/rij/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:7: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
